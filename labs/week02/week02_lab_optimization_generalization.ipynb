# %% [markdown]
# # Week 2 Lab — Optimization, Generalization, and Scaling Intuition
#
# **Goals**
# - Observe how optimization dynamics affect convergence and stability.
# - Compare SGD vs AdamW and learning-rate schedules.
# - Study overfitting and generalization in overparameterized models.
#
# This lab complements Week 2 of the reader.

# %% [markdown]
# ## 0. Setup
# We reuse a small next-token task but vary optimization choices.

# %%
import random, math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

SEED = 123
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %% [markdown]
# ## 1. Data and model
# We reuse the dataset and model from Week 1 for comparability.
# You may copy-paste or import them here.

# %% [markdown]
# ## 2. Optimizers and schedules
# - Compare SGD vs AdamW
# - Fixed LR vs cosine decay

# %% [markdown]
# ## 3. Experiments to run
# 1. Small model, high LR (observe instability)
# 2. Larger model, moderate LR (benign overfitting)
# 3. Same model, different optimizers

# %% [markdown]
# ## 4. Reflection
# Write short notes on:
# - When optimization failed and why
# - Where generalization surprised you
# - Implications for large-scale LLM training
