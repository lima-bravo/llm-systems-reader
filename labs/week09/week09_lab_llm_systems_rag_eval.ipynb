# %% [markdown]
# # Week 9 Lab — LLM Systems: Retrieval, Tool Use, and Evaluation Harnesses
#
# **Goals**
# - Understand LLMs as components in larger systems.
# - Implement a minimal Retrieval-Augmented Generation (RAG) pipeline.
# - Design a basic evaluation harness.
#
# This lab complements Week 9 of the reader.

# %% [markdown]
# ## 0. Setup
# We build a toy RAG system using simple embeddings and cosine similarity.
# The emphasis is on *architecture and interfaces*, not retrieval quality.

# %%
import math
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

SEED = 9
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %% [markdown]
# ## 1. Knowledge base
#
# We define a small document collection that will serve as external memory.

# %% [markdown]
# ## 2. Embedding and retrieval
#
# Embed documents and queries into the same vector space and retrieve top-k.

# %% [markdown]
# ## 3. Prompt construction
#
# Inject retrieved documents into the prompt.
# Observe sensitivity to formatting and ordering.

# %% [markdown]
# ## 4. Tool abstraction
#
# Define retrieval as a tool with a clear interface.
# This mirrors how production LLM systems integrate external capabilities.

# %% [markdown]
# ## 5. Evaluation harness
#
# Create a small test set and compare:
# - base model answers
# - RAG-augmented answers

# %% [markdown]
# ## 6. Reflection
#
# Answer briefly:
# - Where did RAG help or hurt?
# - What failed silently?
# - How would you test this system properly?
