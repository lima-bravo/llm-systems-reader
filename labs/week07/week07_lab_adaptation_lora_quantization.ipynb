# %% [markdown]
# # Week 7 Lab — Model Adaptation, LoRA, and Quantization
#
# **Goals**
# - Understand why full fine-tuning is rarely used in practice.
# - Apply LoRA-style low-rank adaptation to a small model.
# - Explore quantization effects on memory and performance.
#
# This lab complements Week 7 of the reader.

# %% [markdown]
# ## 0. Setup
# We adapt a small pretrained model (or reuse a tiny model from earlier weeks).
# Focus is on *mechanics* and *tradeoffs*, not accuracy.

# %%
import math
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

SEED = 7
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %% [markdown]
# ## 1. Baseline model
#
# Reuse a small language model (e.g. from Week 5) or define a tiny MLP/Transformer.
# Freeze its base weights.

# %% [markdown]
# ## 2. Low-Rank Adaptation (LoRA)
#
# Inject low-rank matrices into linear layers and train only those parameters.

# %% [markdown]
# ## 3. Compare full fine-tuning vs LoRA
#
# Inspect:
# - number of trainable parameters
# - convergence speed
# - overfitting behavior

# %% [markdown]
# ## 4. Quantization (optional)
#
# Cast weights to lower precision and inspect memory usage and output drift.

# %% [markdown]
# ## 5. Reflection
#
# Answer briefly:
# - Why is LoRA preferred in production?
# - What risks does quantization introduce?
# - How would you validate adapted models?
