# %% [markdown]
# # Week 6 Lab — Efficiency, Scaling, and Mixture-of-Experts (MoE)
#
# **Goals**
# - Understand why efficiency matters at scale.
# - Compare dense vs conditional (sparse) computation.
# - Build intuition for Mixture-of-Experts routing.
#
# This lab complements Week 6 of the reader.

# %% [markdown]
# ## 0. Setup
# We use small toy models to study *behavior*, not performance.

# %%
import math
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

SEED = 6
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %% [markdown]
# ## 1. Dense feed-forward baseline
#
# We start with a standard dense MLP block similar to those used in Transformers.

# %% [markdown]
# ## 2. Mixture-of-Experts intuition
#
# Instead of using *all* parameters for every token, MoE activates only a subset.
# This reduces compute while increasing total capacity.

# %% [markdown]
# ## 3. Simple top-k router
#
# We implement a tiny routing network that selects which expert(s) to use.

# %% [markdown]
# ## 4. Compare dense vs MoE behavior
#
# Inspect:
# - routing distributions
# - load balancing
# - output variance

# %% [markdown]
# ## 5. Reflection
#
# Answer briefly:
# - Why does MoE help scaling?
# - What new failure modes appear?
# - What systems controls would you need in production?
