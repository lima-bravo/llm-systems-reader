# %% [markdown]
# # Week 8 Lab — Alignment, Instruction Tuning, and Preference Optimization
#
# **Goals**
# - Understand post-training alignment objectives.
# - Compare supervised instruction tuning and preference-based optimization.
# - Observe how alignment changes model behavior without new knowledge.
#
# This lab complements Week 8 of the reader.

# %% [markdown]
# ## 0. Setup
# We reuse a small pretrained model and focus on behavioral changes.
# The emphasis is on *direction of change*, not benchmark performance.

# %%
import math
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

SEED = 8
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %% [markdown]
# ## 1. Baseline behavior
#
# Probe the base model with prompts that expose:
# - verbosity
# - refusal behavior
# - instruction following

# %% [markdown]
# ## 2. Supervised instruction tuning (SFT)
#
# Fine-tune the model on (instruction, response) pairs.
# Observe changes in tone and structure.

# %% [markdown]
# ## 3. Preference data
#
# Construct simple preference pairs (chosen vs rejected responses).
# These encode human judgment signals.

# %% [markdown]
# ## 4. Preference optimization (conceptual)
#
# Implement a minimal preference loss (DPO-style intuition).
# We focus on loss structure, not convergence.

# %% [markdown]
# ## 5. Reflection
#
# Answer briefly:
# - What changed after alignment?
# - What did *not* change?
# - What risks follow from alignment objectives?
